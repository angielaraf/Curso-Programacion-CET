# %% [markdown]
# **Iniciando con Python**

# %%
nombreP = "Angie"
print(nombreP)
# Out:
# Angie

# %%
edad = 22
print (edad)
edad = 'Angie'
print (edad)
# Out:
# 22
# Angie

# %%
val = True
print (val)
# Out:
# True

# %%
nombrePersona = 'Angie'
apellido = 'Lara'
print (nombrePersona + " " + apellido)
print (apellido * 7)
# Out:
# Angie Lara
# LaraLaraLaraLaraLaraLaraLara

# %% [markdown]
# **Comentarios: Sirven para hacer documentación de código y pruebas**

# %%
#Variable que guarda el teléfono de una persona
telefono = 3123232323
estatura = 1.50
#Muestra la estatura
print (estatura)
# Out:
# 1.5

# %%
nombrePersona = input("Digite el nombre: ")
print(nombrePersona)
# Out:
# Digite el nombre: Angie
# Angie

# %% [markdown]
# **Taller**
#
# No de identificación, nombres, apellidos, dirección, telefono, edad, estado civil, numero de hijos, estatura en centímetros, fecha de contratación(Dia-Mes-Año), sueldo básico, días laborados

# %%
numeroIdentificacion = 100000045
nombres = 'Angie'
apellido = 'Lara'
Direccion = 'Carrera 3 Sur'
Telefono = 3204000000
Edad = 10
Estado_civil = "soltera"
numeroHijos = 10
Estatura = 1.50
FechaContratacion = 17042023
SueldoBasico = 1000000
diasLaborados = 10

print('Numero de identificacion es',numeroIdentificacion),
print('Nombre es', nombres),
print('Apellido es', apellido),
print('Direccion es', Direccion),
print('Telefono es', Telefono),
print('Edad es', Edad),
print('Estado civil es', Estado_civil),
print('Numero de hijos es', numeroHijos),
print('Estatura es',estatura),
print('Fecha de contratacion es', FechaContratacion),
print('El sueldo basico es', SueldoBasico),
print('Trabajo', diasLaborados, 'dias')
# Out:
# Numero de identificacion es 100000045
# Nombre es Angie
# Apellido es Lara
# Direccion es Carrera 3 Sur
# Telefono es 3204000000
# Edad es 10
# Estado civil es soltera
# Numero de hijos es 10
# Estatura es 1.5
# Fecha de contratacion es 17042023
# El sueldo basico es 1000000
# Trabajo 10 dias
